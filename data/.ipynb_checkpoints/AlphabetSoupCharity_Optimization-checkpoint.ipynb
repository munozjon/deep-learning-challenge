# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=['EIN', 'NAME'])

application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts to identify and replace with "Other"
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = [v for v, i in application_df['APPLICATION_TYPE'].value_counts().items() if i < 200]

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure replacement was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts to identify and replace with "Other"
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
for v, i in application_df['CLASSIFICATION'].value_counts().items():
    if i > 1:
        print(v, i)
# Out:
# C1000 17326
# C2000 6074
# C1200 4837
# C3000 1918
# C2100 1883
# C7000 777
# C1700 287
# C4000 194
# C5000 116
# C1270 114
# C2700 104
# C2800 95
# C7100 75
# C1300 58
# C1280 50
# C1230 36
# C1400 34
# C7200 32
# C2300 32
# C1240 30
# C8000 20
# C7120 18
# C1500 16
# C1800 15
# C6000 15
# C1250 14
# C8200 11
# C1238 10
# C1278 10
# C1235 9
# C1237 9
# C7210 7
# C2400 6
# C1720 6
# C4100 6
# C1257 5
# C1600 5
# C1260 3
# C2710 3
# C0 3
# C3200 2
# C1234 2
# C1246 2
# C1267 2
# C1256 2

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = [v for v, i in application_df['CLASSIFICATION'].value_counts().items() if i < 1000]

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure replacement was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
dummies = pd.get_dummies(application_df[['AFFILIATION', 'USE_CASE', 'ORGANIZATION', 'STATUS', \
                         'INCOME_AMT', 'SPECIAL_CONSIDERATIONS']])


dummies.head()
# Out:
#    STATUS  AFFILIATION_CompanySponsored  AFFILIATION_Family/Parent  \
# 0       1                         False                      False
# 1       1                         False                      False
# 2       1                          True                      False
# 3       1                          True                      False
# 4       1                         False                      False
#
#    AFFILIATION_Independent  AFFILIATION_National  AFFILIATION_Other  \
# 0                     True                 False              False
# 1                     True                 False              False
# 2                    False                 False              False
# 3                    False                 False              False
# 4                     True                 False              False
#
#    AFFILIATION_Regional  USE_CASE_CommunityServ  USE_CASE_Heathcare  \
# 0                 False                   False               False
# 1                 False                   False               False
# 2                 False                   False               False
# 3                 False                   False               False
# 4                 False                   False                True
#
#    USE_CASE_Other  ...  INCOME_AMT_1-9999  INCOME_AMT_10000-24999  \
# 0           False  ...              False                   False
# 1           False  ...               True                   False
# 2           False  ...              False                   False
# 3           False  ...              False                    True
# 4           False  ...              False                   False
#
#    INCOME_AMT_100000-499999  INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  \
# 0                     False               False             False
# 1                     False               False             False
# 2                     False               False             False
# 3                     False               False             False
# 4                      True               False             False
#
#    INCOME_AMT_25000-99999  INCOME_AMT_50M+  INCOME_AMT_5M-10M  \
# 0                   False            False              False
# 1                   False            False              False
# 2                   False            False              False
# 3                   False            False              False
# 4                   False            False              False
#
#    SPECIAL_CONSIDERATIONS_N  SPECIAL_CONSIDERATIONS_Y
# 0                      True                     False
# 1                      True                     False
# 2                      True                     False
# 3                      True                     False
# 4                      True                     False
#
# [5 rows x 27 columns]

# %%
data = application_df.drop(columns=['APPLICATION_TYPE', 'CLASSIFICATION', 'AFFILIATION', 'USE_CASE', 'ORGANIZATION', 'STATUS', \
                         'INCOME_AMT', 'SPECIAL_CONSIDERATIONS'])
data = data.join(dummies)

# %%
data.IS_SUCCESSFUL.value_counts()
# Out:
# IS_SUCCESSFUL
# 1    18261
# 0    16038
# Name: count, dtype: int64

# %%
# Split our preprocessed data into our features and target arrays
X = data.drop(columns="IS_SUCCESSFUL")
y = data.IS_SUCCESSFUL

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3,shuffle=True)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_dim = X_train.shape[1]
hidden_layer_1 = 28
hidden_layer_2 = 56
out_put_neuron = 1

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(layers.Dense(units=hidden_layer_1, input_dim = input_dim, activation = "relu"))

# Second hidden layer
nn.add(layers.Dense(units=hidden_layer_2, activation = "relu"))

# Output layer
nn.add(layers.Dense(1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# /opt/anaconda3/envs/dev/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_17 (Dense)                │ (None, 28)             │           812 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 56)             │         1,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 1)              │            57 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,493 (9.74 KB)
#  Trainable params: 2,493 (9.74 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model
nn.compile(optimizer="adam", loss ="binary_crossentropy", metrics=["accuracy"])

# %%
# Train the model
history = nn.fit(X_train_scaled, y_train, epochs=100, validation_split=0.2, batch_size=10)
# Out:
# Epoch 1/100
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 259us/step - accuracy: 0.6771 - loss: 0.6261 - val_accuracy: 0.6951 - val_loss: 0.6023
# Epoch 2/100
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 0s 236us/step - accuracy: 0.6977 - loss: 0.6028 - val_accuracy: 0.6983 - val_loss: 0.5996
# Epoch 3/100
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 0s 236us/step - accuracy: 0.6872 - loss: 0.6091 - val_accuracy: 0.6953 - val_loss: 0.6026
# Epoch 4/100
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s
100
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 0s 238us/step - accuracy: 0.7025 - loss: 0.5978 - val_accuracy: 0.6943 - val_loss: 0.6065
# Epoch 72/100
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 0s 238us/step - accuracy: 0.7002 - loss: 0.5988 - val_accuracy: 0.6953 - val_loss: 0.6071
# Epoch 73/100
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 0s 238us/step - accuracy: 0.7045 - loss: 0.5953 - val_accuracy: 0.6949 - val_loss: 0.6069
# Epoch 74/100
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 0s 239us/step - accuracy: 0.7008 - loss: 0.5956 - val_accuracy: 0.6943 - val_loss: 0.6111
# Epoch 75/100
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 0s 238us/step - accuracy: 0.6982 - loss: 0.5991 - val_accuracy: 0.6951 - val_loss: 0.6077
# Epoch 76/100
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 0s 238us/step - accuracy: 0.7002 - loss: 0.5980 - val_accuracy: 0.6958 - val_loss: 0.6072
# Epoch 77/100
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 0s 238us/step - accuracy: 0.6984 - loss: 0.5969 - val_accuracy: 0.6960 - val_loss: 0.6074
# Epoch 78/100
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 266us/step - accuracy: 0.6986 - loss: 0.5990 - val_accuracy: 0.6962 - val_loss: 0.6049
# Epoch 79/100
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 0s 239us/step - accuracy: 0.7021 - loss: 0.5969 - val_accuracy: 0.6960 - val_loss: 0.6078
# Epoch 80/100
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 0s 239us/step - accuracy: 0.7019 - loss: 0.5970 - val_accuracy: 0.6972 - val_loss: 0.6082
# Epoch 81/100
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 0s 238us/step - accuracy: 0.7021 - loss: 0.5965 - val_accuracy: 0.6941 - val_loss: 0.6074
# Epoch 82/100
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 0s 239us/step - accuracy: 0.7034 - loss: 0.5948 - val_accuracy: 0.6947 - val_loss: 0.6060
# Epoch 83/100
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 0s 240us/step - accuracy: 0.7040 - loss: 0.5934 - val_accuracy: 0.6947 - val_loss: 0.6073
# Epoch 84/100
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 0s 240us/step - accuracy: 0.7044 - loss: 0.5942 - val_accuracy: 0.6962 - val_loss: 0.6054
# Epoch 85/100
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 0s 239us/step - accuracy: 0.7018 - loss: 0.5976 - val_accuracy: 0.6949 - val_loss: 0.6059
# Epoch 86/100
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 0s 240us/step - accuracy: 0.7014 - loss: 0.6002 - val_accuracy: 0.6953 - val_loss: 0.6090
# Epoch 87/100
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 0s 239us/step - accuracy: 0.7049 - loss: 0.5927 - val_accuracy: 0.6955 - val_loss: 0.6086
# Epoch 88/100
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 0s 238us/step - accuracy: 0.7097 - loss: 0.5904 - val_accuracy: 0.6976 - val_loss: 0.6074
# Epoch 89/100
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 266us/step - accuracy: 0.6961 - loss: 0.6009 - val_accuracy: 0.6966 - val_loss: 0.6098
# Epoch 90/100
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 0s 239us/step - accuracy: 0.6956 - loss: 0.6027 - val_accuracy: 0.6968 - val_loss: 0.6071
# Epoch 91/100
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 0s 239us/step - accuracy: 0.7045 - loss: 0.5941 - val_accuracy: 0.6955 - val_loss: 0.6096
# Epoch 92/100
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 0s 238us/step - accuracy: 0.7034 - loss: 0.5961 - val_accuracy: 0.6947 - val_loss: 0.6094
# Epoch 93/100
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 0s 238us/step - accuracy: 0.6985 - loss: 0.5988 - val_accuracy: 0.6955 - val_loss: 0.6078
# Epoch 94/100
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 0s 239us/step - accuracy: 0.6975 - loss: 0.5993 - val_accuracy: 0.6937 - val_loss: 0.6065
# Epoch 95/100
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 0s 240us/step - accuracy: 0.7014 - loss: 0.5970 - val_accuracy: 0.6937 - val_loss: 0.6093
# Epoch 96/100
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 0s 239us/step - accuracy: 0.7023 - loss: 0.5962 - val_accuracy: 0.6970 - val_loss: 0.6115
# Epoch 97/100
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 0s 239us/step - accuracy: 0.7058 - loss: 0.5931 - val_accuracy: 0.6949 - val_loss: 0.6118
# Epoch 98/100
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 1s 266us/step - accuracy: 0.7036 - loss: 0.5971 - val_accuracy: 0.6951 - val_loss: 0.6114
# Epoch 99/100
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 0s 239us/step - accuracy: 0.7058 - loss: 0.5943 - val_accuracy: 0.6947 - val_loss: 0.6244
# Epoch 100/100
# 1921/1921 ━━━━━━━━━━━━━━━━━━━━ 0s 240us/step - accuracy: 0.7079 - loss: 0.5913 - val_accuracy: 0.6960 - val_loss: 0.6069

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 322/322 - 0s - 190us/step - accuracy: 0.7005 - loss: 0.6041
# Loss: 0.604068398475647, Accuracy: 0.70048588514328

# %%
import matplotlib.pyplot as plt

# Plot the training and val_loss
epochs = 100
x_axis = [i for i in range(epochs)]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
plt.figure(figsize=(15,7))
plt.plot(x_axis, loss, color="red", label = "training loss")
plt.plot(x_axis, val_loss, color="green", label="val loss")
plt.grid()
plt.legend()
plt.show()

# %%
# Export our model to HDF5 file
nn.save("AlphabetSoupCharity.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
